# %% [markdown]
# <a href="https://colab.research.google.com/github/adasegroup/ML2021_seminars/blob/master/seminar10/seminar_feature_model_selection_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Feature selection

# %% [markdown]
# A good grasp of feature selection methods leads to better performing models, better understanding of the underlying structure and characteristics of the data and leads to better intuition about the algorithms that underlie many machine learning models.
#
# There are in general two reasons why feature selection is used:
# 1. Reducing the number of features, to reduce overfitting and improve the generalization of models.
# 2. To gain a better understanding of the features and their relationship to the response variables.
#
# In some cases a model may become more interpretable.

# %% [markdown]
# ### Toy function
#
#
# $$
# y = \sin (4\pi x_1 x_2) + 4(x_3 - 0.5)^2 + x_4 + 0.5 x_5 + \varepsilon,
# $$
# where
#
# * $x_1, \ldots, x_5 \sim Uniform([0, 1])$ and $\varepsilon \sim \mathcal{N}(0, 1)$.
# * We also add noise variables $x_6, x_7, x_8$
# * and  $x_9, x_{10}, x_{11}$ strongly correlated with $x_2, x_3, x_4$ generated by $f(x) = x + \mathcal{N}(0, 025)$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline


def function(x, sigma_noise=1, random_state=None):
    if random_state is None:
        random_state = np.random.RandomState()
    y = (np.sin(4 * np.pi * x[:, 0] * x[:, 1])
         + 4 * (x[:, 2] - 0.5)**2
         + x[:, 3]
         + 0.5 * x[:, 4]
         + random_state.normal(0, sigma_noise, size=(len(x)))
        )
    return y

# %% [markdown]
# Let's generate training, validation and test sets

# %%
from sklearn.model_selection import train_test_split


random_state = np.random.RandomState(42)
size = 1500
X = random_state.rand(size, 11)
y = function(X, sigma_noise=0.01, random_state=random_state) 

#Add 3 additional correlated variables (correlated with X1-X3)
X[:, 8:] = X[:, 1:4] + random_state.normal(0, .025, size=(size, 3))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=random_state)
print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (735, 11) (315, 11) (450, 11)

# %% [markdown]
# ## F-test based feature importances
#
# Consider two models, $M_1$ and $M_2$, where $M_1$ has $p_1$ parameters and $M_2$ has $p_2$ parameters,
# and $p_2 > p_1$,
# parameters of $M_1$ are subset of parameters of $M_2$.
#
# * We want to check whether $M_2$ significantly better than $M_1$
# * Let us consider the value
# $$
#     F=\frac{\left({\frac {{\text{RSS}}_{1}-{\text{RSS}}_{2}}{p_{2}-p_{1}}}\right)}
#            {\left({\frac {{\text{RSS}}_{2}}{n-p_{2}-1}}\right)},
# $$
# where $RSS_i$ is the Residual Sum of Squares of $M_i$.
#
# * If $M_2$ is not significantly better than $M_1$, $F$ will have an F-distribution, with $(p_2−p_1, n−p_2)$ degrees of freedom.
# * We rejecte the hypothesis if the $F$ value is greater than the critical value of the F-distribution for some desired false-rejection probability (e.g. 0.05).
#
#
# * Relies on $\mathbf{\color{orange}{\mbox{linearity}}}$ of models $M_1, M_2$

# %% [markdown]
# Now, let's apply F-test to the generated data and analyze results

# %%
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import MinMaxScaler
import pandas as pd


feature_names = np.array(
    ['x1 [sin(x1 x2)]', 'x2 [sin(x1 x2)]', 'x3 [x3^2]', 'x4', 'x5',
     'noise1', 'noise2', 'noise3',
     'corr(x2)', 'corr(x3)', 'corr(x4)'])

feature_scores = pd.DataFrame(columns=['F test'], index=feature_names)

feature_scores['F test'], _ = f_regression(X_train, y_train)

scaler = MinMaxScaler()
feature_scores['F test'] = scaler.fit_transform(feature_scores[['F test']])
feature_scores.round(2)
# Out:
#                  F test
# x1 [sin(x1 x2)]    0.66
# x2 [sin(x1 x2)]    0.30
# x3 [x3^2]          0.01
# x4                 1.00
# x5                 0.77
# noise1             0.00
# noise2             0.01
# noise3             0.05
# corr(x2)           0.31
# corr(x3)           0.01
# corr(x4)           0.95

# %% [markdown]
# **Conclusion**: F-test captures well only linear dependencies!

# %% [markdown]
# ### Mutual Information
#
# This method estimates how much information about the target variable $Y$ is contained in the feature $X$.
# To do this we calculate the value
# $$
# MI(X, Y) = H(Y) - H(Y | X) = \sum_{x, y} p(x, y) \log \frac{p(x, y)}{p(x)p(y)} = D_{KL}(p(x, y) \, ||  \, p(x)p(y)),
# $$
# where $p(x, y), p(x), p(y)$ are joint and marginal densities of random variables $X$ and $Y$.
#
# * $MI(X, Y) = 0 \Leftrightarrow $ $X$ and $Y$ are independent
# * Higher values $\rightarrow$ higher dependency
# * Can capture $\mathbf{\color{green}{\mbox{non-linear}}}$ dependcies

# %% [markdown]
# #### Let's compare F-test and Mutual Information

# %%
from sklearn.feature_selection import mutual_info_regression


method_name = 'Mutual Information'
feature_scores[method_name] = mutual_info_regression(X_train, y_train)

feature_scores[method_name] = scaler.fit_transform(feature_scores[[method_name]])
feature_scores.round(2).style.background_gradient(cmap='Reds', high=1.01)
# Out:
# <style  type="text/css" >
#     #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow0_col0 {
#             background-color:  #fca183;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow0_col1 {
#             background-color:  #fca588;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow1_col0 {
#             background-color:  #fed9c9;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow1_col1 {
#             background-color:  #fcad90;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow2_col0 {
#             background-color:  #fff4ef;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow2_col1 {
#             background-color:  #fb6b4b;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow3_col0 {
#             background-color:  #fb6b4b;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow3_col1 {
#             background-color:  #fc8767;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow4_col0 {
#             background-color:  #fc8f6f;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow4_col1 {
#             background-color:  #fdcbb6;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow5_col0 {
#             background-color:  #fff5f0;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow5_col1 {
#             background-color:  #fff5f0;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow6_col0 {
#             background-color:  #fff4ef;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow6_col1 {
#             background-color:  #fff5f0;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow7_col0 {
#             background-color:  #fff1ea;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow7_col1 {
#             background-color:  #fff5f0;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow8_col0 {
#             background-color:  #fed8c7;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow8_col1 {
#             background-color:  #fcc2aa;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow9_col0 {
#             background-color:  #fff4ef;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow9_col1 {
#             background-color:  #fb7151;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow10_col0 {
#             background-color:  #fb7353;
#         }    #T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow10_col1 {
#             background-color:  #fca486;
#         }</style>
# <table id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deb" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >F test</th>
#         <th class="col_heading level0 col1" >Mutual Information</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deblevel0_row0" class="row_heading level0 row0" >x1 [sin(x1 x2)]</th>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow0_col0" class="data row0 col0" >0.66</td>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow0_col1" class="data row0 col1" >0.64</td>
#     </tr>    <tr>
#         <th id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deblevel0_row1" class="row_heading level0 row1" >x2 [sin(x1 x2)]</th>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow1_col0" class="data row1 col0" >0.3</td>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow1_col1" class="data row1 col1" >0.59</td>
#     </tr>    <tr>
#         <th id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deblevel0_row2" class="row_heading level0 row2" >x3 [x3^2]</th>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow2_col0" class="data row2 col0" >0.01</td>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow2_col1" class="data row2 col1" >1</td>
#     </tr>    <tr>
#         <th id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deblevel0_row3" class="row_heading level0 row3" >x4</th>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow3_col0" class="data row3 col0" >1</td>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow3_col1" class="data row3 col1" >0.82</td>
#     </tr>    <tr>
#         <th id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deblevel0_row4" class="row_heading level0 row4" >x5</th>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow4_col0" class="data row4 col0" >0.77</td>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow4_col1" class="data row4 col1" >0.4</td>
#     </tr>    <tr>
#         <th id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deblevel0_row5" class="row_heading level0 row5" >noise1</th>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow5_col0" class="data row5 col0" >0</td>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow5_col1" class="data row5 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deblevel0_row6" class="row_heading level0 row6" >noise2</th>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow6_col0" class="data row6 col0" >0.01</td>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow6_col1" class="data row6 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deblevel0_row7" class="row_heading level0 row7" >noise3</th>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow7_col0" class="data row7 col0" >0.05</td>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow7_col1" class="data row7 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deblevel0_row8" class="row_heading level0 row8" >corr(x2)</th>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow8_col0" class="data row8 col0" >0.31</td>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow8_col1" class="data row8 col1" >0.46</td>
#     </tr>    <tr>
#         <th id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deblevel0_row9" class="row_heading level0 row9" >corr(x3)</th>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow9_col0" class="data row9 col0" >0.01</td>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow9_col1" class="data row9 col1" >0.96</td>
#     </tr>    <tr>
#         <th id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0deblevel0_row10" class="row_heading level0 row10" >corr(x4)</th>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow10_col0" class="data row10 col0" >0.95</td>
#         <td id="T_fbc00e2e_2d49_11e9_8edd_8c85908f0debrow10_col1" class="data row10 col1" >0.65</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# **Conclusion**: better estimate for non-linear dependencies

# %% [markdown]
# ## Random Forest based feature importances
# Random forests provide straightforward methods for feature ranking
#
# * The importance of a feature is the (normalized) total reduction of the criterion brought by that feature:
#     * For each split in a tree get how much it decreases Gini index.
#     * Take sum of this values over all splits of the feature over all trees

# %%
from sklearn.ensemble import RandomForestRegressor 

random_forest = RandomForestRegressor(n_estimators=100, random_state=42)
random_forest.fit(X_train, y_train)

feature_scores['Random Forest'] = scaler.fit_transform(random_forest.feature_importances_.reshape(-1, 1))
feature_scores.round(2).style.background_gradient(cmap='Reds', high=1.01)
# Out:
# <style  type="text/css" >
#     #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow0_col0 {
#             background-color:  #fca183;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow0_col1 {
#             background-color:  #fca588;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow0_col2 {
#             background-color:  #fb6b4b;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow1_col0 {
#             background-color:  #fed9c9;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow1_col1 {
#             background-color:  #fcad90;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow1_col2 {
#             background-color:  #fca588;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow2_col0 {
#             background-color:  #fff4ef;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow2_col1 {
#             background-color:  #fb6b4b;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow2_col2 {
#             background-color:  #fcc1a8;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow3_col0 {
#             background-color:  #fb6b4b;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow3_col1 {
#             background-color:  #fc8767;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow3_col2 {
#             background-color:  #fdcbb6;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow4_col0 {
#             background-color:  #fc8f6f;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow4_col1 {
#             background-color:  #fdcbb6;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow4_col2 {
#             background-color:  #fdcebb;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow5_col0 {
#             background-color:  #fff5f0;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow5_col1 {
#             background-color:  #fff5f0;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow5_col2 {
#             background-color:  #fff5f0;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow6_col0 {
#             background-color:  #fff4ef;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow6_col1 {
#             background-color:  #fff5f0;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow6_col2 {
#             background-color:  #fff5f0;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow7_col0 {
#             background-color:  #fff1ea;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow7_col1 {
#             background-color:  #fff5f0;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow7_col2 {
#             background-color:  #fff4ef;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow8_col0 {
#             background-color:  #fed8c7;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow8_col1 {
#             background-color:  #fcc2aa;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow8_col2 {
#             background-color:  #fdd1be;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow9_col0 {
#             background-color:  #fff4ef;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow9_col1 {
#             background-color:  #fb7151;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow9_col2 {
#             background-color:  #fedccd;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow10_col0 {
#             background-color:  #fb7353;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow10_col1 {
#             background-color:  #fca486;
#         }    #T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow10_col2 {
#             background-color:  #fee5d9;
#         }</style>
# <table id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0deb" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >F test</th>
#         <th class="col_heading level0 col1" >Mutual Information</th>
#         <th class="col_heading level0 col2" >Random Forest</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0deblevel0_row0" class="row_heading level0 row0" >x1 [sin(x1 x2)]</th>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow0_col0" class="data row0 col0" >0.66</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow0_col1" class="data row0 col1" >0.64</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow0_col2" class="data row0 col2" >1</td>
#     </tr>    <tr>
#         <th id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0deblevel0_row1" class="row_heading level0 row1" >x2 [sin(x1 x2)]</th>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow1_col0" class="data row1 col0" >0.3</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow1_col1" class="data row1 col1" >0.59</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow1_col2" class="data row1 col2" >0.64</td>
#     </tr>    <tr>
#         <th id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0deblevel0_row2" class="row_heading level0 row2" >x3 [x3^2]</th>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow2_col0" class="data row2 col0" >0.01</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow2_col1" class="data row2 col1" >1</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow2_col2" class="data row2 col2" >0.47</td>
#     </tr>    <tr>
#         <th id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0deblevel0_row3" class="row_heading level0 row3" >x4</th>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow3_col0" class="data row3 col0" >1</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow3_col1" class="data row3 col1" >0.82</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow3_col2" class="data row3 col2" >0.4</td>
#     </tr>    <tr>
#         <th id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0deblevel0_row4" class="row_heading level0 row4" >x5</th>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow4_col0" class="data row4 col0" >0.77</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow4_col1" class="data row4 col1" >0.4</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow4_col2" class="data row4 col2" >0.37</td>
#     </tr>    <tr>
#         <th id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0deblevel0_row5" class="row_heading level0 row5" >noise1</th>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow5_col0" class="data row5 col0" >0</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow5_col1" class="data row5 col1" >0</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow5_col2" class="data row5 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0deblevel0_row6" class="row_heading level0 row6" >noise2</th>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow6_col0" class="data row6 col0" >0.01</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow6_col1" class="data row6 col1" >0</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow6_col2" class="data row6 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0deblevel0_row7" class="row_heading level0 row7" >noise3</th>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow7_col0" class="data row7 col0" >0.05</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow7_col1" class="data row7 col1" >0</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow7_col2" class="data row7 col2" >0.01</td>
#     </tr>    <tr>
#         <th id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0deblevel0_row8" class="row_heading level0 row8" >corr(x2)</th>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow8_col0" class="data row8 col0" >0.31</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow8_col1" class="data row8 col1" >0.46</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow8_col2" class="data row8 col2" >0.36</td>
#     </tr>    <tr>
#         <th id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0deblevel0_row9" class="row_heading level0 row9" >corr(x3)</th>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow9_col0" class="data row9 col0" >0.01</td>
#         <td id="T_fc8f7ff6_2d49_11e9_90a9_8c85908f0debrow9_col1" class="data row9 col1" >0.96</td>

# %% [markdown]
# ## L1 and L2 regularizations
#
# Regularization adds penalty to a model in order to prevent overfitting and improve generalization.
#
# * Instead of minimizing a loss function $L(X,Y)$, we minimize $L(X,Y)+\alpha\|w\|$,
#     * where $w$ is the vector of model coefficients,
#     * $\|\cdot\|$ is typically L1 or L2 norm
#     * $\alpha$ is a parameter, specifying the amount of regularization ($\alpha = 0$ implies no regularization).
# * **Lasso** - linear model with L1 regularization.
# * **RidgeRegression** - linear model with L2 regularization
# * **Lasso** efficiently **zeros out** coefficients, RidgeRegression makes them smaller but typically non-zero.
# * $\rightarrow$ Lasso can be used for feature selection

# %%
from sklearn.linear_model import Lasso, Ridge

lasso = Lasso(alpha=0.001, normalize=True).fit(X_train, y_train)
feature_scores['Lasso'] = scaler.fit_transform(np.abs(lasso.coef_).reshape(-1, 1))

ridge = Ridge(normalize=True).fit(X_train, y_train)
feature_scores['Ridge'] = scaler.fit_transform(np.abs(ridge.coef_).reshape(-1, 1))
feature_scores.round(2).style.background_gradient(cmap='Reds', high=1.01)
# Out:
# <style  type="text/css" >
#     #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow0_col0 {
#             background-color:  #fca183;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow0_col1 {
#             background-color:  #fca588;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow0_col2 {
#             background-color:  #fb6b4b;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow0_col3 {
#             background-color:  #fc8e6e;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow0_col4 {
#             background-color:  #fb7050;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow1_col0 {
#             background-color:  #fed9c9;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow1_col1 {
#             background-color:  #fcad90;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow1_col2 {
#             background-color:  #fca588;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow1_col3 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow1_col4 {
#             background-color:  #fcc3ab;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow2_col0 {
#             background-color:  #fff4ef;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow2_col1 {
#             background-color:  #fb6b4b;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow2_col2 {
#             background-color:  #fcc1a8;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow2_col3 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow2_col4 {
#             background-color:  #fff0e9;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow3_col0 {
#             background-color:  #fb6b4b;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow3_col1 {
#             background-color:  #fc8767;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow3_col2 {
#             background-color:  #fdcbb6;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow3_col3 {
#             background-color:  #fb6b4b;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow3_col4 {
#             background-color:  #fc8b6b;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow4_col0 {
#             background-color:  #fc8f6f;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow4_col1 {
#             background-color:  #fdcbb6;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow4_col2 {
#             background-color:  #fdcebb;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow4_col3 {
#             background-color:  #fc8767;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow4_col4 {
#             background-color:  #fb6b4b;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow5_col0 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow5_col1 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow5_col2 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow5_col3 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow5_col4 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow6_col0 {
#             background-color:  #fff4ef;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow6_col1 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow6_col2 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow6_col3 {
#             background-color:  #fff0e9;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow6_col4 {
#             background-color:  #fee5d8;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow7_col0 {
#             background-color:  #fff1ea;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow7_col1 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow7_col2 {
#             background-color:  #fff4ef;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow7_col3 {
#             background-color:  #fff0e9;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow7_col4 {
#             background-color:  #fee3d6;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow8_col0 {
#             background-color:  #fed8c7;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow8_col1 {
#             background-color:  #fcc2aa;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow8_col2 {
#             background-color:  #fdd1be;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow8_col3 {
#             background-color:  #fcb296;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow8_col4 {
#             background-color:  #fcc1a8;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow9_col0 {
#             background-color:  #fff4ef;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow9_col1 {
#             background-color:  #fb7151;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow9_col2 {
#             background-color:  #fedccd;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow9_col3 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow9_col4 {
#             background-color:  #fff3ed;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow10_col0 {
#             background-color:  #fb7353;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow10_col1 {
#             background-color:  #fca486;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow10_col2 {
#             background-color:  #fee5d9;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow10_col3 {
#             background-color:  #fff5f0;
#         }    #T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow10_col4 {
#             background-color:  #fc9373;
#         }</style>
# <table id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0deb" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >F test</th>
#         <th class="col_heading level0 col1" >Mutual Information</th>
#         <th class="col_heading level0 col2" >Random Forest</th>
#         <th class="col_heading level0 col3" >Lasso</th>
#         <th class="col_heading level0 col4" >Ridge</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0deblevel0_row0" class="row_heading level0 row0" >x1 [sin(x1 x2)]</th>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow0_col0" class="data row0 col0" >0.66</td>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow0_col1" class="data row0 col1" >0.64</td>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow0_col2" class="data row0 col2" >1</td>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow0_col3" class="data row0 col3" >0.78</td>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow0_col4" class="data row0 col4" >0.97</td>
#     </tr>    <tr>
#         <th id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0deblevel0_row1" class="row_heading level0 row1" >x2 [sin(x1 x2)]</th>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow1_col0" class="data row1 col0" >0.3</td>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow1_col1" class="data row1 col1" >0.59</td>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow1_col2" class="data row1 col2" >0.64</td>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow1_col3" class="data row1 col3" >0</td>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow1_col4" class="data row1 col4" >0.45</td>
#     </tr>    <tr>
#         <th id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0deblevel0_row2" class="row_heading level0 row2" >x3 [x3^2]</th>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow2_col0" class="data row2 col0" >0.01</td>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow2_col1" class="data row2 col1" >1</td>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow2_col2" class="data row2 col2" >0.47</td>
#         <td id="T_fc9e4f06_2d49_11e9_a66c_8c85908f0debrow2_col3" class="data row2 col3" >0</td>

# %% [markdown]
# ### Task
#
# What if we remove correlated component?
#
# **Task**:
# 1. Build `RidgeRegression` model using all features. Check coefficients for features `x4` and `corr(x4)`.
# 2. Build `RidgeRegression` model without the last features. Check coefficient for feature `x4`.
# 3. What can you conclude?

# %%
# Your code here
model = Ridge(normalize=True).fit(X_train[:, :-1], y_train)
print(model.coef_[3])

model = Ridge(normalize=True).fit(X_train, y_train)
print(model.coef_[[3, -1]])
# Out:
# 0.40489270252468695
# [0.27624341 0.25783574]

# %% [markdown]
# ## Forward-backward methods
#
# The idea is to add or delete features and look how loss function or some other criteria changes.
#
# Decision about adding or deleting a feature may be made based on:
#
# - AIC
# - BIC
# - validation error
# - Mallows $C_p$
# - `model.score()`

# %% [markdown]
# ### Task. Implement forward method
#
# Implement the following algorithm:
#
# 1. Start with empty list of features.
# 2. Add feature that increases model quality the most (use `model.score()` function)
# 3. Iterate step 2 until required number of features is selected

# %%
def forward_steps(X, y, n_features, model, X_test, y_test):
    """
    Parameters
    ==========
        X: ndarray - training inputs
        y: ndarray - training targets
        n_features: int - number of features to select
        model: sklearn model
        X_test: ndarray - test inputs
        y_test: ndarray - test targets
        
    Returns
    =======
        list - list of features
    """
    
    feat_list = []
    
    # Your code here
    
    # fill variable feat_list with
    # the selected features and return it
    
    for i in range(n_features):
        max_score = -np.inf
        active_idx = -1
        for j in range(X.shape[1]):
            if j not in feat_list:
                feat_list.append(j)
                
                model.fit(X[:, feat_list], y)
                current_score = model.score(X_test[:, feat_list], y_test)

                feat_list.pop()

                if current_score > max_score:
                    max_score = current_score
                    active_idx = j
        feat_list.append(active_idx)
        
        print('{:.2f}: {}'.format(max_score, feat_list))
    return feat_list

# %%
features_idx = forward_feat = forward_steps(X_train, y_train, 5,
                                            random_forest,
                                            X_test, y_test)
print(feature_names[features_idx])
# Out:
# -0.21: [10]
# 0.07: [10, 2]
# 0.27: [10, 2, 0]
# 0.66: [10, 2, 0, 1]
# 0.66: [10, 2, 0, 1, 9]
# ['corr(x4)' 'x3 [x3^2]' 'x1 [sin(x1 x2)]' 'x2 [sin(x1 x2)]' 'corr(x3)']

# %% [markdown]
# ## Permutation based feature importance
#
#
# **Idea**: measure how much the score (accuracy, F1, R^2, etc.) decreases when a feature is not available.
#
# It can be done by:
#
# * Removing feature from the dataset, re-training the estimator and check the score - can be $\mathbf{\color{orange}{\mbox{computationally intensive}}}$
#
# * Replace feature with random noise - now the column doesn't contain useful information.
#
#   * Noise should be from the same distribution as original feature values (as otherwise estimator may fail).
#   * -> $\mathbf{\color{blue}{\mbox{shuffle values for a feature}}}$, i.e. use other examples’ feature values
#   * Allows to estimate feature importance for generalization on new data set
#
# To do that one can remove feature from the dataset, re-train the estimator and check the score. But it requires re-training an estimator for each feature, which can be computationally intensive. Also, it shows what may be important within a dataset, not what is important within a concrete trained model.
#
#
# The method is most suitable for computing feature importances when a number of columns (features) is not huge; it can be resource-intensive otherwise.

# %% [markdown]
# ### Task. Implement permutation importance
#
# 1. Using fitted model calculate its base_score - score, obtained using all features
# 2. Take one feature column and replace its values by the permuted values, calculate
#    the score and subtract it from base_score, i.e. calculate `score_decrease`
# 3. Repeat step 2 several times and calculte mean `score_decrease`
# 4. Do steps 2 and 3 for each feature

# %%
def _permutation_importance(model, X, y, 
                            feature, n_iters=5, random_state=None):
    """
    Calculate permutation importances for the given feature
    
    Parameters
    ==========
        model: sklearn-style fitted model with and score() methods
        X: ndarray - training inputs
        y: ndarray - training targets
        feature: int - index of feature for which importance should be
                       calculated
        n_iters: int - number of permutation rounds
        
    Returns
    =======
        ndarray: feature importances
    """
    if random_state is None:
        random_state = np.random.RandomState(42)
    if isinstance(random_state, int):
        random_state = np.random.RandomState(random_state)

    base_score = model.score(X, y)
    
    importance = None
    
    # Your code here
    
    #
    scores = []
    for i in range(n_iters):
        X_copy = X.copy()
        permutation = random_state.permutation(X.shape[0])
        X_copy[:, feature] = X[permutation, feature]
            
        scores.append(base_score - model.score(X_copy, y))
        
    importance = np.mean(scores)

    return importance

def get_permutation_importance(model, X, y, n_iters=20, random_state=None):
    permutation_importances = np.zeros(X.shape[1])
    for i in range(X.shape[1]):
        permutation_importances[i] = _permutation_importance(model, X_val, y_val, i)
    return permutation_importances

# %%
random_forest = RandomForestRegressor(n_estimators=100).fit(X_train, y_train)
permutation_importances = get_permutation_importance(random_forest, X_val, y_val)

feature_scores['Permutation Importance'] = scaler.fit_transform(permutation_importances.reshape(-1, 1))
feature_scores.round(2).style.background_gradient(cmap='Reds', high=1.01)
# Out:
# <style  type="text/css" >
#     #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow0_col0 {
#             background-color:  #fca183;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow0_col1 {
#             background-color:  #fca588;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow0_col2 {
#             background-color:  #fb6b4b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow0_col3 {
#             background-color:  #fc8e6e;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow0_col4 {
#             background-color:  #fb7050;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow0_col5 {
#             background-color:  #fb6b4b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow0_col6 {
#             background-color:  #fb6b4b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow1_col0 {
#             background-color:  #fed9c9;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow1_col1 {
#             background-color:  #fcad90;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow1_col2 {
#             background-color:  #fca588;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow1_col3 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow1_col4 {
#             background-color:  #fcc3ab;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow1_col5 {
#             background-color:  #fcc2aa;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow1_col6 {
#             background-color:  #fb6b4b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow2_col0 {
#             background-color:  #fff4ef;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow2_col1 {
#             background-color:  #fb6b4b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow2_col2 {
#             background-color:  #fcc1a8;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow2_col3 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow2_col4 {
#             background-color:  #fff0e9;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow2_col5 {
#             background-color:  #fee3d6;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow2_col6 {
#             background-color:  #fb6b4b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow3_col0 {
#             background-color:  #fb6b4b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow3_col1 {
#             background-color:  #fc8767;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow3_col2 {
#             background-color:  #fdcbb6;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow3_col3 {
#             background-color:  #fb6b4b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow3_col4 {
#             background-color:  #fc8b6b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow3_col5 {
#             background-color:  #fee2d5;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow3_col6 {
#             background-color:  #fb6b4b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow4_col0 {
#             background-color:  #fc8f6f;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow4_col1 {
#             background-color:  #fdcbb6;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow4_col2 {
#             background-color:  #fdcebb;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow4_col3 {
#             background-color:  #fc8767;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow4_col4 {
#             background-color:  #fb6b4b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow4_col5 {
#             background-color:  #feeae1;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow4_col6 {
#             background-color:  #fb6b4b;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow5_col0 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow5_col1 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow5_col2 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow5_col3 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow5_col4 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow5_col5 {
#             background-color:  #fff4ef;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow5_col6 {
#             background-color:  #fee7dc;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow6_col0 {
#             background-color:  #fff4ef;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow6_col1 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow6_col2 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow6_col3 {
#             background-color:  #fff0e9;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow6_col4 {
#             background-color:  #fee5d8;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow6_col5 {
#             background-color:  #fff4ef;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow6_col6 {
#             background-color:  #fdd4c2;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow7_col0 {
#             background-color:  #fff1ea;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow7_col1 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow7_col2 {
#             background-color:  #fff4ef;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow7_col3 {
#             background-color:  #fff0e9;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow7_col4 {
#             background-color:  #fee3d6;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow7_col5 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow7_col6 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow8_col0 {
#             background-color:  #fed8c7;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow8_col1 {
#             background-color:  #fcc2aa;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow8_col2 {
#             background-color:  #fdd1be;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow8_col3 {
#             background-color:  #fcb296;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow8_col4 {
#             background-color:  #fcc1a8;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow8_col5 {
#             background-color:  #fee4d8;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow8_col6 {
#             background-color:  #fca082;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow9_col0 {
#             background-color:  #fff4ef;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow9_col1 {
#             background-color:  #fb7151;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow9_col2 {
#             background-color:  #fedccd;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow9_col3 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow9_col4 {
#             background-color:  #fff3ed;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow9_col5 {
#             background-color:  #ffebe2;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow9_col6 {
#             background-color:  #fc8666;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow10_col0 {
#             background-color:  #fb7353;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow10_col1 {
#             background-color:  #fca486;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow10_col2 {
#             background-color:  #fee5d9;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow10_col3 {
#             background-color:  #fff5f0;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow10_col4 {
#             background-color:  #fc9373;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow10_col5 {
#             background-color:  #feeae1;
#         }    #T_3f2b4542_2deb_11e9_93a2_8c85908f0debrow10_col6 {

# %% [markdown]
# It is useful to visualize feature importances using bar plot

# %%
def plot_feature_scores(X, scores):
    sorting_idx = scores.argsort()

    plt.figure(figsize=(10, 0.3 * len(scores)))
    plt.barh(range(len(scores)), scores[sorting_idx], height=0.5)
    plt.yticks(range(len(scores)), X.columns[sorting_idx])
    for i, v in enumerate(scores[sorting_idx]):

        if np.isfinite(v):
            v_str = '{:.3f}'.format(v) if v != int(v) else '{}'.format(int(v))
            plt.text(v + 0.005 * scores.max(), i - 0.22, v_str)
    plt.grid(True)
    plt.ylim([-0.5, len(scores) - 0.5])
    plt.show()

# %%
plot_feature_scores(pd.DataFrame(X_train), permutation_importances)

# %% [markdown]
# ### Task 2. Use RFECV to get optimal number of features

# %% [markdown]
# To choose number of features automatically, RFECV module may be used.

# %%
from sklearn.feature_selection import RFECV

# use RFECV to select features, use step = 50
rfe = RFECV(random_forest, n_jobs=-1, verbose=True, step=1, cv=3)
rfe.fit(X_train, y_train)

feature_scores['RFECV'] = scaler.fit_transform(-rfe.ranking_.astype(float).reshape(-1, 1))
feature_scores.round(2).style.background_gradient(cmap='Reds', high=1.01)
# Out:
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# <style  type="text/css" >
#     #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow0_col0 {
#             background-color:  #fca183;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow0_col1 {
#             background-color:  #fca588;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow0_col2 {
#             background-color:  #fb6b4b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow0_col3 {
#             background-color:  #fc8e6e;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow0_col4 {
#             background-color:  #fb7050;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow0_col5 {
#             background-color:  #fb6b4b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow0_col6 {
#             background-color:  #fb6b4b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow1_col0 {
#             background-color:  #fed9c9;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow1_col1 {
#             background-color:  #fcad90;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow1_col2 {
#             background-color:  #fca588;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow1_col3 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow1_col4 {
#             background-color:  #fcc3ab;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow1_col5 {
#             background-color:  #fdc9b3;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow1_col6 {
#             background-color:  #fb6b4b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow2_col0 {
#             background-color:  #fff4ef;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow2_col1 {
#             background-color:  #fb6b4b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow2_col2 {
#             background-color:  #fcc1a8;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow2_col3 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow2_col4 {
#             background-color:  #fff0e9;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow2_col5 {
#             background-color:  #fee2d5;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow2_col6 {
#             background-color:  #fb6b4b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow3_col0 {
#             background-color:  #fb6b4b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow3_col1 {
#             background-color:  #fc8767;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow3_col2 {
#             background-color:  #fdcbb6;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow3_col3 {
#             background-color:  #fb6b4b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow3_col4 {
#             background-color:  #fc8b6b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow3_col5 {
#             background-color:  #fed9c9;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow3_col6 {
#             background-color:  #fb6b4b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow4_col0 {
#             background-color:  #fc8f6f;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow4_col1 {
#             background-color:  #fdcbb6;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow4_col2 {
#             background-color:  #fdcebb;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow4_col3 {
#             background-color:  #fc8767;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow4_col4 {
#             background-color:  #fb6b4b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow4_col5 {
#             background-color:  #fee8de;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow4_col6 {
#             background-color:  #fb6b4b;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow5_col0 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow5_col1 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow5_col2 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow5_col3 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow5_col4 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow5_col5 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow5_col6 {
#             background-color:  #fee7dc;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow6_col0 {
#             background-color:  #fff4ef;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow6_col1 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow6_col2 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow6_col3 {
#             background-color:  #fff0e9;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow6_col4 {
#             background-color:  #fee5d8;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow6_col5 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow6_col6 {
#             background-color:  #fdd4c2;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow7_col0 {
#             background-color:  #fff1ea;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow7_col1 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow7_col2 {
#             background-color:  #fff4ef;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow7_col3 {
#             background-color:  #fff0e9;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow7_col4 {
#             background-color:  #fee3d6;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow7_col5 {
#             background-color:  #fff4ee;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow7_col6 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow8_col0 {
#             background-color:  #fed8c7;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow8_col1 {
#             background-color:  #fcc2aa;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow8_col2 {
#             background-color:  #fdd1be;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow8_col3 {
#             background-color:  #fcb296;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow8_col4 {
#             background-color:  #fcc1a8;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow8_col5 {
#             background-color:  #fed9c9;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow8_col6 {
#             background-color:  #fca082;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow9_col0 {
#             background-color:  #fff4ef;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow9_col1 {
#             background-color:  #fb7151;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow9_col2 {
#             background-color:  #fedccd;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow9_col3 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow9_col4 {
#             background-color:  #fff3ed;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow9_col5 {
#             background-color:  #ffece3;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow9_col6 {
#             background-color:  #fc8666;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow10_col0 {
#             background-color:  #fb7353;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow10_col1 {
#             background-color:  #fca486;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow10_col2 {
#             background-color:  #fee5d9;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow10_col3 {
#             background-color:  #fff5f0;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow10_col4 {
#             background-color:  #fc9373;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow10_col5 {
#             background-color:  #fff0e8;
#         }    #T_0388fe74_2d4a_11e9_90ce_8c85908f0debrow10_col6 {

# %%
# output selected number of features
print("Number selected features =", np.sum(rfe.support_))
# Out:
# Number selected features = 5

# %% [markdown]
# ### Task. Calculate quality of the model with the selected features
#
#
# * Use RandomForestRegression
# * Use test set and model's `score()` function to calculate model error
# * Try F-test, RandomForest embedded feature importances, Permutation Importance and RFECV
# * Select 5 features for each feature importance method

# %%
def compare_methods(model, X_train, y_train, X_val, y_val, X_test, y_test):
    methods = {
        'F test': lambda X, y, X_val, y_val: f_regression(X, y)[0],

        'RandomForest': lambda X, y, X_val, y_val: model.fit(X, y).feature_importances_,

        'PermutationImportance': lambda X, y, X_val, y_val: get_permutation_importance(
            model.fit(X, y), X_val, y_val),

        'RFECV': lambda X, y, X_val, y_val: -RFECV(
            model, n_jobs=-1, step=1, cv=3).fit(X, y).ranking_
    }

    model_scores = pd.DataFrame(columns=list(methods.keys()))

    # Your code here

    for fs_method in methods:
        scores = methods[fs_method](X_train, y_train, X_val, y_val)
        features_idx = np.argsort(-scores)[:5]
        model.fit(X_train[:, features_idx], y_train)
        model_scores[fs_method] = [model.score(X_test[:, features_idx], y_test)]
        
    return model_scores

# %%
compare_methods(random_forest, X_train, y_train, X_val, y_val, X_test, y_test)

# %%
results = [compare_methods(random_forest, X_train, y_train, X_val, y_val, X_test, y_test) for _ in range(10)]

# %%
pd.concat(results, axis=0, ignore_index=True).describe()
# Out:
#           F test  RandomForest  PermutationImportance      RFECV
# count  10.000000     10.000000              10.000000  10.000000
# mean    0.603331      0.659247               0.685992   0.659305
# std     0.003962      0.009859               0.008230   0.016829
# min     0.596281      0.651572               0.675191   0.635955
# 25%     0.601508      0.653711               0.678588   0.648737
# 50%     0.602843      0.656519               0.685930   0.658651
# 75%     0.606166      0.660470               0.691702   0.661704
# max     0.609313      0.685493               0.697331   0.697188

# %% [markdown]
# ### Akaike Information criterion (AIC)
#
# Suppose that we have a statistical model of some data. Let $k$ be the number of estimated parameters in the model.
# Let $\hat{L}$ be the maximum value of the likelihood function for the model.
# Then the AIC value of the model is the following.
#
# $$
# \mathrm {AIC} = 2k - 2\ln(\hat{L})
# $$
#
#
# * We would like to minimize AIC
# * AIC rewards goodness of fit (likelihood function)
# * It includes a penalty - an increasing function of the number of parameters.
#
# AIC is founded in information theory. Suppose that the data is generated by some unknown process $f$.
# We consider two candidate models to represent $f$: $_1$ and $M_2$.
# If we knew $f$, then we could find the information lost from using $M_1$ to represent $f$ by calculating the Kullback–Leibler divergence,
# $DKL(f || M_1)$;
# similarly, the information lost from using $M_2$ to represent $f$ could be found by calculating $DKL(f || M_2)$.
# We would then choose the candidate model that minimized the information loss.
#
# AIC - is an approximate value of how much more information is lost by $M_1$ than by $M_2$.
#
# Valid only asymptotically

# %% [markdown]
# ### Bayesian Information Criterion
#
# Defined as
#
# $$
# {\rm BIC} = \ln(N)k - 2\ln(\hat{L})
# $$
#
# * We would like to minimize BIC
# * It can be shown that for model $M$ and given data set $D$ the posterior probability is approximately
#
# $$
# p(M | D) \propto \exp(-{\rm BIC}) p(M)
# $$

# %% [markdown]
# ### Task 4. Use LassoLarsIC to choose optimal alpha based on AIC and BIC
#
# * $\alpha$ affects the number of non-zero coefficients $\Rightarrow$ allows to control number of parameters in the model
# * LARS algorithm for lasso for each possible number of non-zero coefficients estimates $\alpha$ that gives such number of non-zeros.
# * $\Rightarrow$ using AIC or BIC we can choose $\alpha$.
#
# **Task**:
# 1. choose $\alpha$ using AIC, print non-zero feature's names
# 2. choose $\alpha$ using BIC, print non-zero feature's names
# 3. Compare

# %%
from sklearn.linear_model import LassoLarsIC

# Your code here
model = LassoLarsIC('bic')
model.fit(X_train, y_train)
print(feature_names[np.where(model.coef_)])
# Out:
# ['x1 [sin(x1 x2)]' 'x4' 'x5' 'corr(x2)']

# %%
model = LassoLarsIC('aic')
model.fit(X_train, y_train)
print(feature_names[np.where(model.coef_)])
# Out:
# ['x1 [sin(x1 x2)]' 'x4' 'x5' 'noise2' 'noise3' 'corr(x2)']
